# %% [markdown]
# # Chatbot using Transformers (Hugging Face)
#
# ## Internship Assignment – NLP Task 3
#
# This project builds a conversational chatbot using a pre-trained transformer model from Hugging Face.
#
# ### Features:
# - Uses DialoGPT for conversation
# - Handles continuous interaction
# - Generates dynamic responses
# - Maintains conversation context
# - Exit command supported
#
# ### Pipeline:
# User Input → Model → Response → Loop

# %%
# !pip install transformers torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/10.1 MB 6.4 MB/s eta 0:00:02
#    ------- -------------------------------- 1.8/10.1 MB 5.2 MB/s eta 0:00:02
#    ------------ --------------------------- 3.1/10.1 MB 5.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.2/10.1 MB 5.3 MB/s eta 0:00:02
#    -------------------- ------------------- 5.2/10.1 MB 5.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.0/10.1 MB 4.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.1/10.1 MB 4.8 MB/s eta 0:00:01
#    ------------------------------ --------- 7.6/10.1 MB 4.8 MB/s eta 0:00:01
#    --------------------------------- ------ 8.4/10.1 MB 4.4 MB/s eta 0:00:01
#    ------------------------------------- -- 9.4/10.1 MB 4.5 MB/s eta 0:00:01
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

# %%
model_name = "microsoft/DialoGPT-medium"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)
# Out:
# ...
# config.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/863M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/293 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/863M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
print("Chatbot: Hello! I am your AI assistant. Type 'exit' to end.\n")

chat_history_ids = None

while True:
    user_input = input("You: ")
    
    if user_input.lower() in ["exit", "quit"]:
        print("Chatbot: Goodbye! Have a great day 😊")
        break

    # Encode input
    new_input_ids = tokenizer.encode(user_input + tokenizer.eos_token, return_tensors='pt')

    # Append to chat history
    bot_input_ids = torch.cat([chat_history_ids, new_input_ids], dim=-1) if chat_history_ids is not None else new_input_ids

    # Generate response
    chat_history_ids = model.generate(
        bot_input_ids,
        max_length=1000,
        pad_token_id=tokenizer.eos_token_id,
        do_sample=True,
        top_k=50,
        top_p=0.95,
        temperature=0.7
    )

    # Decode response
    bot_response = tokenizer.decode(chat_history_ids[:, bot_input_ids.shape[-1]:][0], skip_special_tokens=True)

    print(f"Chatbot: {bot_response}\n")
# Out:
# Chatbot: Hello! I am your AI assistant. Type 'exit' to end.
# You:  hello

# %% [markdown]
# ## Key Features
#
# - Uses transformer-based model (DialoGPT)
# - Maintains conversation context using chat history
# - Generates dynamic responses (no hardcoding)
# - Supports continuous interaction
# - Handles exit condition
